# %%
import requests
from bs4 import BeautifulSoup
headers = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:105.0) Gecko/20100101 Firefox/105.0'}
resp = requests.get('https://news.google.com/search?q=microsoft&', headers = headers)

#print(resp.content)
soup = BeautifulSoup(resp.content)

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html dir="ltr" lang="en-US"><head><base href="https://news.google.com/"/><meta content="origin" name="referrer"/><link href="https://news.google.com/search" rel="canonical"/><meta content="width=device-width,initial-scale=1,minimal-ui" name="viewport"/><meta content="AcBy5YFny2HQgVUCR18tO5YUTf6MpVlcJqGTd-a9-SI" name="google-site-verification"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="News" name="application-name"/><meta content="News" name="apple-mobile-web-app-title"/><meta content="black" name="apple-mobile-web-app-status-bar-style"/><meta content="white" name="theme-color"/><meta content="no" name="msapplication-tap-highlight"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w16" rel="shortcut icon" sizes="16x16"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w24" rel="shortcut icon" sizes="24x24"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w32" rel="shortcut icon" sizes="32x32"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w48" rel="shortcut icon" sizes="48x48"/><link href="//www.gstatic.com" rel="preconnect"/><link href="//fonts.gstatic.com" rel="preconnect"/><link href="//lh3.googleusercontent.com" rel="preconnect"/><link href="//lh4.googleusercontent.com" rel="preconnect"/><link href="//lh5.googleusercontent.com" rel="preconnect"/><link href="//lh6.googleusercontent.com" rel="preconnect"/><link href="//ssl.gstatic.com" rel="preconnect"/><link href="//maps.googleapis.com" rel="preconnect"/><link href="https://www.google-analytics.com/analytics.js" rel="preconnect"/><link href="https://fonts.googleapis.com/css?family=Google+Sans+Text:400,500,700,400i,500i,700i" rel="stylesheet"/><link crossorigin="use-credentials" href="_/DotsSplashUi/manifest.json" rel="manifest"/><link href="/?lfhs=2" rel="home"/><link href="/?lfhs=2" rel="msapplication-starturl"/><link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="icon" sizes="192x192"/><link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="apple-touch-icon-precomposed" sizes="192x192"/><link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="msapplication-square192x192logo" sizes="192x192"/><link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="icon" sizes="512x512"/><link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="apple-touch-icon-precomposed" sizes="512x512"/><link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="msapplication-square512x512logo" sizes="512x512"/><link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="icon" sizes="1024x1024"/><link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="apple-touch-icon-precomposed" sizes="1024x1024"/><link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="msapplication-square1024x1024logo" sizes="1024x1024"/><link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="icon" sizes="120x120"/><link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="msapplication-square120x120logo" sizes="120x120"/><link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="icon" sizes="152x152"/><link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="msapplication-square152x152logo" sizes="152x152"/><link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="icon" sizes="167x167"/><link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="apple-touch-icon-precomposed" sizes="167x167"/><link href="//ssl. ...
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# 'use strict';var a=window,d=a.performance,l=k();a.cc_latency_start_time=d&&d.now?0:d&&d.timing&&d.timing.navigationStart?d.timing.navigationStart:l;function k(){return d&&d.now?d.now():(new Date).getTime()}function n(e){if(d&&d.now&&d.mark){var g=d.mark(e);if(g)return g.startTime;if(d.getEntriesByName&&(e=d.getEntriesByName(e).pop()))return e.startTime}return k()}a.onaft=function(){n("aft")};a._isLazyImage=function(e){return e.hasAttribute("data-src")||e.hasAttribute("data-ils")||"lazy"===e.getAttribute("loading")};
# a.l=function(e){function g(b){var c={};c[b]=k();a.cc_latency.push(c)}function m(b){var c=n("iml");b.setAttribute("data-iml",c);return c}a.cc_aid=e;a.iml_start=a.cc_latency_start_time;a.css_size=0;a.cc_latency=[];a.ccTick=g;a.onJsLoad=function(){g("jsl")};a.onCssLoad=function(){g("cssl")};a._isVisible=function(b,c){if(!c||"none"==c.style.display)return!1;var f=b.defaultView;if(f&&f.getComputedStyle&&(f=f.getComputedStyle(c),"0px"==f.height||"0px"==f.width||"hidden"==f.visibility))return!1;if(!c.getBoundingClientRect)return!0;
# var h=c.getBoundingClientRect();c=h.left+a.pageXOffset;f=h.top+a.pageYOffset;if(0>f+h.height||0>c+h.width||0>=h.height||0>=h.width)return!1;b=b.documentElement;return f<=(a.innerHeight||b.clientHeight)&&c<=(a.innerWidth||b.clientWidth)};a._recordImlEl=m;document.documentElement.addEventListener("load",function(b){b=b.target;var c;"IMG"!=b.tagName||b.hasAttribute("data-iid")||a._isLazyImage(b)||b.hasAttribute("data-noaft")||(c=m(b));if(a.aft_counter&&(b=a.aft_counter.indexOf(b),-1!==b&&(b=1===a.aft_counter.splice(b,
# 1).length,0===a.aft_counter.length&&b&&c)))a.onaft(c)},!0);a.prt=-1;a.wiz_tick=function(){var b=n("prt");a.prt=b}};}).call(this);
# l('A35Fe')</script><script nonce="Wlqc5JcCHoITsfmOUUzf4w">var _F_cssRowKey = 'boq-dots.DotsSplashUi_desktop_ms.6mp2GFEyi-k.L.F4.O';var _F_combinedSignature = 'ALs0n2Nfo5Fri62gIohET6ixiDXr0bD5-Q';function _DumpException(e) {throw e;}</script><style data-href="https://www.gstatic.com/_/mss/boq-dots/_/ss/k=boq-dots.DotsSplashUi_desktop_ms.6mp2GFEyi-k.L.F4.O/am=iCaQBWgACYA/d=1/ed=1/rs=ALs0n2N3HwjbKJAxZ0TYzHBiGOjYPqHVaQ/m=search,_b,_tp,_r" nonce="DSwUr7JUNxiRpp8RdAQVlw">html{height:100%;overflow:hidden}body{height:100%;overflow:hidden;-moz-osx-font-smoothing:grayscale;color:rgba(0,0,0,.87);font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif;margin:0;-moz-text-size-adjust:100%;-moz-text-size-adjust:100%;text-size-adjust:100%}textarea{font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif}a{text-decoration:none;color:#2962ff}img{border:none}#apps-debug-tracers{display:none}html{overflow:visible}body{overflow:visible;overflow-y:scroll}@keyframes quantumWizBoxInkSpread{0%{transform:translate(-50%,-50%) scale(0.2)}to{transform:translate(-50%,-50%) scale(2.2)}}@keyframes quantumWizIconFocusPulse{0%{transform:translate(-50%,-50%) scale(1.5);opacity:0}to{transform:translate(-50%,-50%) scale(2);opacity:1}}@keyframes quantumWizRadialInkSpread{0%{transform:scale(1.5);opacity:0}to{transform:scale(2.5);opacity:1}}@keyframes quantumWizRadialInkFocusPulse{0%{transform:scale(2);opacity:0}to{transform:scale(2.5);opacity:1}}.O0WRkf{-moz-user-select:none;-moz-transition:background .2s .1s;transition:background .2s .1s;border:0;-moz-border-radius:3px;border-radius:3px;cursor:pointer;display:inline-block;font-size:14px;font-weight:500;min-width:4em;outline:none;overflow:hidden;position:relative;text-align:center;text-transform:uppercase;z-index:0}.A9jyad{font-size:13px;line-height:16px}.zZhnYe{-moz-transition:box-shadow .28s cubic-bezier(0.4,0,0.2,1);transition:box-shadow .28s cubic-bezier(0.4,0,0.2,1);background:#dfdfdf;-moz-box-shadow:0px 2px 2px 0px rgba(0,0,0,.14),0px 3px 1px -2px rgba(0,0,0,.12),0px 1px 5px 0px rgba(0,0,0,.2);box-shadow:0px 2px 2px 0px rgba(0,0,0,.14),0px 3px 1px -2px rgba(0,0,0,.12),0px 1px 5px 0px rgba(0,0,0,.2)}.zZhnYe.qs41qe{-moz-transition:box-shadow .28s cubic-bezier(0.4,0,0.2,1);transition:box-shadow .28s cubic-bezier(0.4,0,0.2,1);-moz-transition:background .8s;transition:background .8s;-moz-box-shadow:0px 8px 10px 1px rgba(0,0,0,.14),0px 3px 14px 2px rgba(0,0,0,.12),0px 5px 5px -3px rgba(0,0,0,.2);box-shadow:0px 8px 10px 1px rgba(0,0,0,.14),0px 3px 14px 2px rgba(0,0,0,.12),0px 5px 5px -3px rgba(0,0,0,.2)}.e3Duub,.e3Duub a,.e3Duub a:hover,.e3Duub a:link,.e3Duub a:visited{background:#4285f4;color:#fff}.HQ8yf,.HQ8yf a{color:#4285f4}.UxubU,.UxubU a{color:#fff}.ZFr60d{position:absolute;top:0;right:0;bottom:0;left:0;background-color:transparent}.O0WRkf.u3bW4e .ZFr60d{background-color:rgba(0,0,0,.12)}.UxubU.u3bW4e .ZFr60d{background-color:rgba(255,255,255,.3)}.e3Duub.u3bW4e .ZFr60d{background-color:rgba(0,0,0,0.122)}.HQ8yf.u3bW4e .ZFr60d{background-color:rgba(66,133,244,.15)}.Vwe4Vb{-moz-transform:translate(-50%,-50%) scale(0);transform:translate(-50%,-50%) scale(0);transition:opacity .2s ease,visibility 0s ease .2s,transform 0s ease .2s;transition:opacity .2s ease,visibility 0s ease .2s,transform 0s ease .2s,-webkit-transform 0s ease .2s;transition:opacity .2s ease,visibility 0s ease .2s,-webkit-transform 0s ease .2s;background-size:cover;left:0;opacity:0;pointer-events:none;position:absolute;top:0;visibility:hidden}.O0WRkf.qs41qe .Vwe4Vb{-moz-transform:translate(-50%,-50%) scale(2.2);transform:translate(-50%,-50%) scale(2.2);opacity:1;visibility:visible}.O0WRkf.qs41qe.M9Bg4d .Vwe4Vb{transition:-webkit-transform 0.3s cubic-bezier(0,0,0.2,1),opacity .2s cubic-bezier(0,0,0.2,1);transition:opacity .2s cubic-bezier(0,0,0.2,1),-webkit-transform 0.3s cubic-bezier(0,0,0.2,1);transition:transform 0.3s cubic-bezier(0,0,0.2,1),opacity .2s cubic-bezier(0,0,0.2,1);transition:transform 0.3s cubic-bezier(0,0,0.2,1),opacity .2s cubic- ...
# /*# sourceURL=/_/mss/boq-dots/_/ss/k=boq-dots.DotsSplashUi_desktop_ms.6mp2GFEyi-k.L.F4.O/am=iCaQBWgACYA/d=1/ed=1/rs=ALs0n2N3HwjbKJAxZ0TYzHBiGOjYPqHVaQ/m=search,_b,_tp,_r */</style><script nonce="Wlqc5JcCHoITsfmOUUzf4w">onCssLoad();</script><style nonce="DSwUr7JUNxiRpp8RdAQVlw">@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu72xKOzY.woff2)format('woff2');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F;}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu5mxKOzY.woff2)format('woff2');unicode-range:U+0301,U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116;}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu7mxKOzY.woff2)format('woff2');unicode-range:U+1F00-1FFF;}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4WxKOzY.woff2)format('woff2');unicode-range:U+0370-03FF;}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu7WxKOzY.woff2)format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+0128-0129,U+0168-0169,U+01A0-01A1,U+01AF-01B0,U+1EA0-1EF9,U+20AB;}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu7GxKOzY.woff2)format('woff2');unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF;}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxK.woff2)format('woff2');unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD;}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fCRc4EsA.woff2)format('woff2');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F;}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fABc4EsA.woff2)format('woff2');unicode-range:U+0301,U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116;}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fCBc4EsA.woff2)format('woff2');unicode-range:U+1F00-1FFF;}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBxc4EsA.woff2)format('woff2');unicode-range:U+0370-03FF;}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fCxc4EsA.woff2)format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+0128-0129,U+0168-0169,U+01A0-01A1,U+01AF-01B0,U+1EA0-1EF9,U+20AB;}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fChc4EsA.woff2)format('woff2');unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF;}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc4.woff2)format('woff2');unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD;}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfCRc4EsA.woff2)format('woff2');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F;}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfABc4EsA.woff2)format('woff2');unicode-range:U+0301,U+0 ...
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# 'use strict';var b=this||self;/*
#
#  Copyright 2011 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  Copyright 2013 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# var d={};function aa(c,e){if(null===e)return!1;if("contains"in c&&1==e.nodeType)return c.contains(e);if("compareDocumentPosition"in c)return c==e||!!(c.compareDocumentPosition(e)&16);for(;e&&c!=e;)e=e.parentNode;return e==c};function ba(c,e){return function(f){f||(f=window.event);return e.call(c,f)}}function u(c){c=c.target||c.srcElement;!c.getAttribute&&c.parentNode&&(c=c.parentNode);return c}var y="undefined"!=typeof navigator&&/Macintosh/.test(navigator.userAgent),ca="undefined"!=typeof navigator&&!/Opera/.test(navigator.userAgent)&&/WebKit/.test(navigator.userAgent),da={A:1,INPUT:1,TEXTAREA:1,SELECT:1,BUTTON:1};function ea(){this._mouseEventsPrevented=!0}
# var ha={Enter:13," ":32},ia={A:13,BUTTON:0,CHECKBOX:32,COMBOBOX:13,FILE:0,GRIDCELL:13,LINK:13,LISTBOX:13,MENU:0,MENUBAR:0,MENUITEM:0,MENUITEMCHECKBOX:0,MENUITEMRADIO:0,OPTION:0,RADIO:32,RADIOGROUP:32,RESET:0,SUBMIT:0,SWITCH:32,TAB:0,TREE:13,TREEITEM:13},ja={CHECKBOX:!0,FILE:!0,OPTION:!0,RADIO:!0},ka={COLOR:!0,DATE:!0,DATETIME:!0,"DATETIME-LOCAL":!0,EMAIL:!0,MONTH:!0,NUMBER:!0,PASSWORD:!0,RANGE:!0,SEARCH:!0,TEL:!0,TEXT:!0,TEXTAREA:!0,TIME:!0,URL:!0,WEEK:!0},la={A:!0,AREA:!0,BUTTON:!0,DIALOG:!0,IMG:!0,
# INPUT:!0,LINK:!0,MENU:!0,OPTGROUP:!0,OPTION:!0,PROGRESS:!0,SELECT:!0,TEXTAREA:!0};/*
#
#  Copyright 2020 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# var z=b._jsa||{};z._cfc=void 0;z._aeh=void 0;/*
#
#  Copyright 2005 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# function ma(){this.o=[];this.g=[];this.j=[];this.m={};this.h=null;this.l=[]}function na(c){return String.prototype.trim?c.trim():c.replace(/^\s+/,"").replace(/\s+$/,"")}
# function oa(c,e){return function x(a,p){p=void 0===p?!0:p;var m=e;if("click"==m&&(y&&a.metaKey||!y&&a.ctrlKey||2==a.which||null==a.which&&4==a.button||a.shiftKey))m="clickmod";else{var g=a.which||a.keyCode;!g&&a.key&&(g=ha[a.key]);ca&&3==g&&(g=13);if(13!=g&&32!=g)g=!1;else{var h=u(a),n;(n="keydown"!=a.type||!!(!("getAttribute"in h)||(h.getAttribute("type")||h.tagName).toUpperCase()in ka||"BUTTON"==h.tagName.toUpperCase()||h.type&&"FILE"==h.type.toUpperCase()||h.isContentEditable)||a.ctrlKey||a.shiftKey||
# a.altKey||a.metaKey||(h.getAttribute("type")||h.tagName).toUpperCase()in ja&&32==g)||((n=h.tagName in da)||(n=h.getAttributeNode("tabindex"),n=null!=n&&n.specified),n=!(n&&!h.disabled));if(n)g=!1;else{n=(h.getAttribute("role")||h.type||h.tagName).toUpperCase();var w=!(n in ia)&&13==g;h="INPUT"!=h.tagName.toUpperCase()||!!h.type;g=(0==ia[n]%g||w)&&h}}g&&(m="clickkey")}h=a.srcElement||a.target;g=A(m,a,h,"",null);var k,B;for(n=h;n&&n!=this;n=n.__owner||("#document-fragment"!==(null==(k=n.parentNode)?
# void 0:k.nodeName)?n.parentNode:null==(B=n.parentNode)?void 0:B.host)){var l=n;var r=void 0;w=l;var t=m,wa=a;var q=w.__jsaction;if(!q){var F;q=null;"getAttribute"in w&&(q=w.getAttribute("jsaction"));if(F=q){q=d[F];if(!q){q={};for(var L=F.split(pa),ya=L?L.length:0,M=0;M<ya;M++){var C=L[M];if(C){var N=C.indexOf(":"),fa=-1!=N;q[fa?na(C.substr(0,N)):qa]=fa?na(C.substr(N+1)):C}}d[F]=q}w.__jsaction=q}else q=ra,w.__jsaction=q}"maybe_click"==t&&q.click?(r=t,t="click"):"clickkey"==t?t="click":"click"!=t||
# q.click||(t="clickonly");r=z._cfc&&q.click?z._cfc(w,wa,q,t,r):{eventType:r?r:t,action:q[t]||"",event:null,ignore:!1};if(r.ignore||r.action)break}r&&(g=A(r.eventType,r.event||a,h,r.action||"",l,g.timeStamp));g&&"touchend"==g.eventType&&(g.event._preventMouseEvents=ea);if(r&&r.action){if(k="clickkey"==m)k=u(a),k=(k.type||k.tagName).toUpperCase(),(k=32==(a.which||a.keyCode)&&"CHECKBOX"!=k)||(k=u(a),B=k.tagName.toUpperCase(),h=(k.getAttribute("role")||"").toUpperCase(),k="BUTTON"===B||"BUTTON"===h?!0:
# !(k.tagName.toUpperCase()in la)||"A"===B||"SELECT"===B||(k.getAttribute("type")||k.tagName).toUpperCase()in ja||(k.getAttribute("type")||k.tagName).toUpperCase()in ka?!1:!0);k&&(a.preventDefault?a.preventDefault():a.returnValue=!1);if("mouseenter"==m||"mouseleave"==m||"pointerenter"==m||"pointerleave"==m)if(k=a.relatedTarget,!("mouseover"==a.type&&"mouseenter"==m||"mouseout"==a.type&&"mouseleave"==m||"pointerover"==a.type&&"pointerenter"==m||"pointerout"==a.type&&"pointerleave"==m)||k&&(k===l||aa(l,
# k)))g.action="",g.actionElement=null;else{m={};for(var v in a)"function"!==typeof a[v]&&"srcElement"!==v&&"target"!==v&&(m[v]=a[v]);m.type="mouseover"==a.type?"mouseenter":"mouseout"==a.type?"mouseleave":"pointerover"==a.type?"pointerenter":"pointerleave";m.target=m.srcElement=l;m.bubbles=!1;g.event=m;g.targetElement=l}}else g.action="",g.actionElement=null;l=g;c.h&&!l.event.a11ysgd&&(v=A(l.eventType,l.event,l.targetElement,l.action,l.actionElement,l.timeStamp),"clickonly"==v.eventType&&(v.eventType=
# "click"),c.h(v,!0));if(l.actionElement){if(c.h){if(!l.actionElement||"A"!=l.actionElement.tagName||"click"!=l.eventType&&"clickmod"!=l.eventType||(a.preventDefault?a.preventDefault():a.returnValue=!1),(a=c.h(l))&&p){x.call(this,a,!1);return}}else{if((p=b.document)&&!p.createEvent&&p.createEventObject)try{var O=p.createEventObject(a)}catch(Ea){O=a}else O=a;l.event=O;c.l.push(l)}z._aeh&&z._aeh(l)}}}
# function A(c,e,f,a,p,x){return{eventType:c,event:e,targetElement:f,action:a,actionElement:p,timeStamp:x||Date.now()}}
# function sa(c,e){return function(f){var a=c,p=e,x=!1;"mouseenter"==a?a="mouseover":"mouseleave"==a?a="mouseout":"pointerenter"==a?a="pointerover":"pointerleave"==a&&(a="pointerout");if(f.addEventListener){if("focus"==a||"blur"==a||"error"==a||"load"==a||"toggle"==a)x=!0;f.addEventListener(a,p,x)}else f.attachEvent&&("focus"==a?a="focusin":"blur"==a&&(a="focusout"),p=ba(f,p),f.attachEvent("on"+a,p));return{eventType:a,i:p,capture:x}}}
# function D(c,e,f){if(!c.m.hasOwnProperty(e)){var a=oa(c,e);f=sa(f||e,a);c.m[e]=a;c.o.push(f);for(a=0;a<c.g.length;++a){var p=c.g[a];p.h.push(f.call(null,p.g))}"click"==e&&D(c,"keydown")}}ma.prototype.i=function(c){return this.m[c]};function ta(c){var e=E,f=c.g;ua&&(f.style.cursor="pointer");for(f=0;f<e.o.length;++f)c.h.push(e.o[f].call(null,c.g))}function va(c){for(var e=xa,f=0;f<e.length;++f)if(e[f].g!=c.g&&za(e[f].g,c.g))return!0;return!1}
# function za(c,e){for(;c!=e&&e.parentNode;)e=e.parentNode;return c==e}var ua="undefined"!=typeof navigator&&/iPhone|iPad|iPod/.test(navigator.userAgent),pa=/\s*;\s*/,qa="click",ra={};var G=window,E=new ma;var Aa=G.document.documentElement,H=new function(c){this.g=c;this.h=[]}(Aa),I;b:{for(var J=0;J<E.g.length;J++)if(za(E.g[J].g,Aa)){I=!0;break b}I=!1}
# if(I)E.j.push(H);else{ta(H);E.g.push(H);for(var xa=E.j.concat(E.g),K=[],P=[],Q=0;Q<E.g.length;++Q){var R=E.g[Q];if(va(R)){K.push(R);for(var S=0;S<R.h.length;++S){var T=R.g,U=R.h[S];T.removeEventListener?T.removeEventListener(U.eventType,U.i,U.capture):T.detachEvent&&T.detachEvent("on"+U.eventType,U.i)}R.h=[]}else P.push(R)}for(var V=0;V<E.j.length;++V){var W=E.j[V];va(W)?K.push(W):(P.push(W),ta(W))}E.g=P;E.j=K}D(E,"click");D(E,"dblclick");D(E,"focus");D(E,"focusin");D(E,"blur");D(E,"error");D(E,"focusout");
# D(E,"keydown");D(E,"keyup");D(E,"keypress");D(E,"load");D(E,"mouseover");D(E,"mouseout");D(E,"mouseenter");D(E,"mouseleave");D(E,"submit");D(E,"touchstart");D(E,"touchend");D(E,"touchmove");D(E,"auxclick");D(E,"change");D(E,"compositionstart");D(E,"compositionupdate");D(E,"compositionend");D(E,"beforeinput");D(E,"input");D(E,"textinput");D(E,"copy");D(E,"cut");D(E,"paste");D(E,"mousedown");D(E,"mouseup");D(E,"wheel");D(E,"contextmenu");D(E,"dragover");D(E,"dragenter");D(E,"dragleave");D(E,"drop");
# D(E,"dragstart");D(E,"dragend");D(E,"pointerdown");D(E,"pointermove");D(E,"pointerup");D(E,"pointercancel");D(E,"pointerenter");D(E,"pointerleave");D(E,"pointerover");D(E,"pointerout");D(E,"gotpointercapture");D(E,"lostpointercapture");D(E,"ended");D(E,"loadedmetadata");D(E,"pagehide");D(E,"pageshow");D(E,"visibilitychange");var Ba,Ca;"onwebkitanimationend"in G&&(Ba="webkitAnimationEnd");D(E,"animationend",Ba);"onwebkittransitionend"in G&&(Ca="webkitTransitionEnd");D(E,"transitionend",Ca);
# var Da=function(c){return{trigger:function(e){var f=c.i(e.type);f||(D(c,e.type),f=c.i(e.type));var a=e.target||e.srcElement;f&&f.call(a.ownerDocument.documentElement,e)},bind:function(e){c.h=e;c.l&&(0<c.l.length&&e(c.l),c.l=null)}}}(E),X=["BOQ_wizbind"],Y=window||b;X[0]in Y||"undefined"==typeof Y.execScript||Y.execScript("var "+X[0]);for(var Z;X.length&&(Z=X.shift());)X.length||void 0===Da?Y[Z]&&Y[Z]!==Object.prototype[Z]?Y=Y[Z]:Y=Y[Z]={}:Y[Z]=Da;}).call(this);
# </script><script href="https://www.gstatic.com/_/mss/boq-dots/_/js/k=boq-dots.DotsSplashUi_desktop_ms.en_US.haE5r_8_y-E.es5.O/am=iCaQBWgACYA/d=1/excm=_b,_r,_tp,search/ed=1/dg=0/wt=2/rs=ALs0n2PljjsQnQDYkxoLtcEsYFhvX7ekRA/m=_b,_tp,_r" id="base-js" nocollect="" nonce="Wlqc5JcCHoITsfmOUUzf4w">"use strict";this.default_DotsSplashUi_desktop_ms=this.default_DotsSplashUi_desktop_ms||{};(function(_){var window=this;
# try{
# var baa,caa,iaa,laa,naa,oaa,paa,qaa,lb,uaa,Baa,zaa,Aaa,Daa,Eaa,Lc,Faa,Tc,Uc,Gaa,Haa,nd,Jaa,Kaa,Maa,Naa,Oaa,Paa,Qaa,Saa,Taa,Vaa,Waa,Raa,Yaa,Zaa,bba,$aa,cba,aba,dba,eba,gba,Ld,fba,lba,pba,qba,Dba,ie,Fba,me,ne,Lba,Mba,Wba,Zba,aca,bca,cca,eca,fca,kca,mca,nca,qca,Aca,wca,Ve,Cca,Dca,We,Gca,Ica,Jca,Lca,Mca,Nca,Oca,Pca,Tca,Uca,Wca,Yca,aaa,Zca,of,$ca,qf,ada,sf,cda,tf,jda,kda,mda,oda,nda,wf,pda,qda;_.ba=function(a){return function(){return aaa[a].apply(this,arguments)}};_.da=function(a,b){return aaa[a]=b};
# _.ea=function(a,b){if(Error.captureStackTrace)Error.captureStackTrace(this,_.ea);else{var c=Error().stack;c&&(this.stack=c)}a&&(this.message=String(a));void 0!==b&&(this.cause=b);this.o=!0};_.fa=function(a,b){a=a.split("%s");for(var c="",d=a.length-1,e=0;e<d;e++)c+=a[e]+(e<b.length?b[e]:"%s");_.ea.call(this,c+a[d])};_.ia=function(a){_.ha.setTimeout(function(){throw a;},0)};_.ja=function(a){a&&"function"==typeof a.vd&&a.vd()};
# baa=function(a){for(var b=0,c=arguments.length;b<c;++b){var d=arguments[b];_.ma(d)?baa.apply(null,d):_.ja(d)}};caa=function(a){_.na?a(_.na):oa.push(a)};_.qa=function(){!_.na&&_.pa&&_.daa((0,_.pa)());return _.na};_.daa=function(a){_.na=a;oa.forEach(function(b){b(_.na)});oa=[]};_.m=function(a){_.na&&eaa(a)};_.u=function(){_.na&&faa(_.na)};_.ta=function(a){return a[a.length-1]};_.ua=function(a,b,c){for(var d="string"===typeof a?a.split(""):a,e=a.length-1;0<=e;--e)e in d&&b.call(c,d[e],e,a)};
# _.wa=function(a,b,c){b=_.va(a,b,c);return 0>b?null:"string"===typeof a?a.charAt(b):a[b]};_.va=function(a,b,c){for(var d=a.length,e="string"===typeof a?a.split(""):a,f=0;f<d;f++)if(f in e&&b.call(c,e[f],f,a))return f;return-1};_.gaa=function(a,b){for(var c="string"===typeof a?a.split(""):a,d=a.length-1;0<=d;d--)if(d in c&&b.call(void 0,c[d],d,a))return d;return-1};_.ya=function(a,b){return 0<=(0,_.xa)(a,b)};_.haa=function(a){if(!Array.isArray(a))for(var b=a.length-1;0<=b;b--)delete a[b];a.length=0};
# _.za=function(a,b){_.ya(a,b)||a.push(b)};_.Ca=function(a,b){b=(0,_.xa)(a,b);var c;(c=0<=b)&&_.Aa(a,b);return c};_.Aa=function(a,b){return 1==Array.prototype.splice.call(a,b,1).length};_.Ea=function(a,b,c){var d=0;_.ua(a,function(e,f){b.call(c,e,f,a)&&_.Aa(a,f)&&d++});return d};_.Ha=function(a){return Array.prototype.concat.apply([],arguments)};_.Ia=function(a){var b=a.length;if(0<b){for(var c=Array(b),d=0;d<b;d++)c[d]=a[d];return c}return[]};
# _.Ka=function(a,b){for(var c=1;c<arguments.length;c++){var d=arguments[c];if(_.ma(d)){var e=a.length||0,f=d.length||0;a.length=e+f;for(var g=0;g<f;g++)a[e+g]=d[g]}else a.push(d)}};_.La=function(a,b,c,d){Array.prototype.splice.apply(a,iaa(arguments,1))};iaa=function(a,b,c){return 2>=arguments.length?Array.prototype.slice.call(a,b):Array.prototype.slice.call(a,b,c)};
# _.Pa=function(a,b){b=b||a;for(var c=0,d=0,e={};d<a.length;){var f=a[d++],g=_.Ma(f)?"o"+_.Na(f):(typeof f).charAt(0)+f;Object.prototype.hasOwnProperty.call(e,g)||(e[g]=!0,b[c++]=f)}b.length=c};_.kaa=function(a,b,c){return _.jaa(a,c||_.Qa,!1,b)};_.jaa=function(a,b,c,d){for(var e=0,f=a.length,g;e<f;){var h=e+(f-e>>>1),l=void 0;c?l=b.call(void 0,a[h],h,a):l=b(d,a[h]);0<l?e=h+1:(f=h,g=!l)}return g?e:-e-1};_.Sa=function(a,b){a.sort(b||_.Qa)};
# _.Ta=function(a,b){if(!_.ma(a)||!_.ma(b)||a.length!=b.length)return!1;for(var c=a.length,d=laa,e=0;e<c;e++)if(!d(a[e],b[e]))return!1;return!0};_.Qa=function(a,b){return a>b?1:a<b?-1:0};laa=function(a,b){return a===b};_.maa=function(a,b){var c={};(0,_.Wa)(a,function(d,e){c[b.call(void 0,d,e,a)]=d});return c};_.Xa=function(a,b){var c=[],d=0,e=a;void 0!==b&&(d=a,e=b);if(0>e-d)return[];for(a=d;a<e;a+=1)c.push(a);return c};
# _.Ya=function(a){for(var b=[],c=0;c<arguments.length;c++){var d=arguments[c];if(Array.isArray(d))for(var e=0;e<d.length;e+=8192)for(var f=_.Ya.apply(null,iaa(d,e,e+8192)),g=0;g<f.length;g++)b.push(f[g]);else b.push(d)}return b};naa=function(){};_.ab=function(){var a=_.ha.navigator;return a&&(a=a.userAgent)?a:""};_.db=function(a){return _.bb(_.ab(),a)};_.fb=function(){return _.db("Trident")||_.db("MSIE")};_.gb=function(){return _.db("Firefox")||_.db("FxiOS")};
# _.ib=function(){return _.db("Safari")&&!(_.hb()||_.db("Coast")||_.db("Opera")||_.db("Edge")||_.db("Edg/")||_.db("OPR")||_.gb()||_.db("Silk")||_.db("Android"))};_.hb=function(){return(_.db("Chrome")||_.db("CriOS"))&&!_.db("Edge")||_.db("Silk")};oaa=function(){return _.db("Android")&&!(_.hb()||_.gb()||_.db("Opera")||_.db("Silk"))};paa=function(a){var b={};a.forEach(function(c){b[c[0]]=c[1]});return function(c){return b[c.find(function(d){return d in b})]||""}};
# qaa=function(a){var b=_.ab();if("Internet Explorer"===a){if(_.fb())if((a=/rv: *([\d\.]*)/.exec(b))&&a[1])b=a[1];else{a="";var c=/MSIE +([\d\.]+)/.exec(b);if(c&&c[1])if(b=/Trident\/(\d.\d)/.exec(b),"7.0"==c[1])if(b&&b[1])switch(b[1]){case "4.0":a="8.0";break;case "5.0":a="9.0";break;case "6.0":a="10.0";break;case "7.0":a="11.0"}else a="7.0";else a=c[1];b=a}else b="";return b}var d=RegExp("([A-Z][\\w ]+)/([^\\s]+)\\s*(?:\\((.*?)\\))?","g");c=[];for(var e;e=d.exec(b);)c.push([e[1],e[2],e[3]||void 0]);
# b=paa(c);switch(a){case "Opera":if(_.db("Opera"))return b(["Version","Opera"]);if(_.db("OPR"))return b(["OPR"]);break;case "Microsoft Edge":if(_.db("Edge"))return b(["Edge"]);if(_.db("Edg/"))return b(["Edg"]);break;case "Chromium":if(_.hb())return b(["Chrome","CriOS","HeadlessChrome"])}return"Firefox"===a&&_.gb()||"Safari"===a&&_.ib()||"Android Browser"===a&&oaa()||"Silk"===a&&_.db("Silk")?(b=c[2])&&b[1]||"":""};
# _.jb=function(a){a=qaa(a);if(""===a)return NaN;a=a.split(".");return 0===a.length?NaN:Number(a[0])};_.kb=function(){return _.db("Android")};lb=function(){return _.db("iPhone")&&!_.db("iPod")&&!_.db("iPad")};_.nb=function(){return lb()||_.db("iPad")||_.db("iPod")};
# _.qb=function(){var a=_.ab(),b="";_.db("Windows")?(b=/Windows (?:NT|Phone) ([0-9.]+)/,b=(a=b.exec(a))?a[1]:"0.0"):_.nb()?(b=/(?:iPhone|iPod|iPad|CPU)\s+OS\s+(\S+)/,b=(a=b.exec(a))&&a[1].replace(/_/g,".")):_.db("Macintosh")?(b=/Mac OS X ([0-9_.]+)/,b=(a=b.exec(a))?a[1].replace(/_/g,"."):"10"):_.pb(_.ab(),"KaiOS")?(b=/(?:KaiOS)\/(\S+)/i,b=(a=b.exec(a))&&a[1]):_.kb()?(b=/Android\s+([^\);]+)(\)|;)/,b=(a=b.exec(a))&&a[1]):_.db("CrOS")&&(b=/(?:CrOS\s+(?:i686|x86_64)\s+([0-9.]+))/,b=(a=b.exec(a))&&a[1]);
# return b||""};_.vb=function(a,b,c){for(var d in a)b.call(c,a[d],d,a)};_.yb=function(a,b){var c={},d;for(d in a)b.call(void 0,a[d],d,a)&&(c[d]=a[d]);return c};_.zb=function(a,b,c){var d={},e;for(e in a)d[e]=b.call(c,a[e],e,a);return d};_.Ab=function(a){var b=0,c;for(c in a)b++;return b};_.raa=function(a){for(var b in a)return a[b]};_.Cb=function(a){var b=[],c=0,d;for(d in a)b[c++]=a[d];return b};_.Db=function(a){var b=[],c=0,d;for(d in a)b[c++]=d;return b};_.Kb=function(a,b){return null!==a&&b in a};
# _.saa=function(a,b){for(var c in a)if(a[c]==b)return!0;return!1};_.Lb=function(a){for(var b in a)return!1;return!0};_.Sb=function(a,b){b in a&&delete a[b]};_.Tb=function(a){var b={},c;for(c in a)b[c]=a[c];return b};_.$b=function(a,b){for(var c,d,e=1;e<arguments.length;e++){d=arguments[e];for(c in d)a[c]=d[c];for(var f=0;f<taa.length;f++)c=taa[f],Object.prototype.hasOwnProperty.call(d,c)&&(a[c]=d[c])}};
# uaa=function(a){var b=arguments.length;if(1==b&&Array.isArray(arguments[0]))return uaa.apply(null,arguments[0]);for(var c={},d=0;d<b;d++)c[arguments[d]]=!0;return c};
# Baa=function(a){if(a instanceof _.ac)return'url("'+_.mc(a).replace(/</g,"%3c").replace(/[\\"]/g,"\\$&")+'")';if(a instanceof _.rc)a=_.Cc(a);else{a=String(a);var b=a.replace(vaa,"$1").replace(vaa,"$1").replace(waa,"url");if(xaa.test(b)){if(b=!yaa.test(a)){for(var c=b=!0,d=0;d<a.length;d++){var e=a.charAt(d);"'"==e&&c?b=!b:'"'==e&&b&&(c=!c)}b=b&&c&&zaa(a)}a=b?Aaa(a):"zClosurez"}else a="zClosurez"}if(/[{;}]/.test(a))throw new _.fa("Value does not allow [{;}], got: %s.",[a]);return a};
# zaa=function(a){for(var b=!0,c=/^[-_a-zA-Z0-9]$/,d=0;d<a.length;d++){var e=a.charAt(d);if("]"==e){if(b)return!1;b=!0}else if("["==e){if(!b)return!1;b=!1}else if(!b&&!c.test(e))return!1}return b};Aaa=function(a){return a.replace(waa,function(b,c,d,e){var f="";d=d.replace(/^(['"])(.*)\1$/,function(g,h,l){f=h;return l});b=_.Dc(d).Sl();return c+f+b+f+e})};Daa=function(a){return null==a||_.Gc(a)?a:"string"===typeof a?Caa(a):null};_.Gc=function(a){return Hc&&null!=a&&a instanceof Uint8Array};
# Eaa=function(a){if(a!==_.Jc)throw Error("Q");};Lc=function(a,b){Object.isFrozen(a)||(Kc?a[Kc]|=b:void 0!==a.As?a.As|=b:Object.defineProperties(a,{As:{value:b,configurable:!0,writable:!0,enumerable:!1}}))};Faa=function(a,b){Object.isExtensible(a)&&(Kc?a[Kc]&&(a[Kc]&=~b):void 0!==a.As&&(a.As&=~b))};_.Rc=function(a){var b;Kc?b=a[Kc]:b=a.As;return null==b?0:b};Tc=function(a,b){Kc?a[Kc]=b:void 0!==a.As?a.As=b:Object.defineProperties(a,{As:{value:b,configurable:!0,writable:!0,enumerable:!1}})};
# Uc=function(a){Lc(a,1);return a};Gaa=function(a){Lc(a,17);return a};_.ed=function(a){return a?!!(_.Rc(a)&2):!1};_.fd=function(a){Lc(a,2);return a};_.hd=function(a){Lc(a,16);return a};_.id=function(a){if(!Array.isArray(a))throw Error("S");Faa(a,16)};_.kd=function(a,b){Tc(b,(_.Rc(a)|0)&-51)};Haa=function(a,b){Tc(b,(_.Rc(a)|18)&-33)};_.md=function(a){return _.ed(a.Cf)};nd=function(a){return null!==a&&"object"===typeof a&&!Array.isArray(a)&&a.constructor===Object};
# Jaa=function(a,b){if(null!=a)if("string"===typeof a)a=a?new _.od(a,_.Jc):_.rd();else if(a.constructor!==_.od)if(_.Gc(a))a=Iaa(a);else{if(!b)throw Error();a=void 0}return a};Kaa=function(a){a instanceof _.od&&(Eaa(_.Jc),a=a.tb||"");return a};_.Laa=function(a,b,c){var d=!1;if(null!=a&&"object"===typeof a&&!(d=Array.isArray(a))&&a.YR===sd)return a;if(d)return new b(a);if(c)return new b};Maa=function(a,b){a=""+a;b=""+b;return a>b?1:a<b?-1:0};
# Naa=function(a,b,c,d){a=_.Laa(a,b,!0);c?_.fd(a.Cf):d&&(a=_.td(a));return a};Oaa=function(a){return a};Paa=function(a){return a};Qaa=function(a){return a};Saa=function(a,b){a=a||{};b=b||{};var c={},d;for(d in a)c[d]=0;for(var e in b)c[e]=0;for(var f in c)if(!Raa(a,f,a[f],b,f,b[f]))return!1;return!0};Taa=function(a){return a&&"object"===typeof a?a.Cf||a:a};
# Vaa=function(a,b){if(null==b)return!1;a=a.j;b=b.j;if(a.size!=b.size)return!1;a=a.entries();for(var c;!(c=a.next()).done;)if(c=c.value,!_.Uaa(c[1],b.get(c[0])))return!1;return!0};Waa=function(a,b,c,d){if(null==d)d=[];else if(!Array.isArray(d))return null;return b[c]=ud(a,d)};
# Raa=function(a,b,c,d,e,f){c=Kaa(c);f=Kaa(f);c=Taa(c);f=Taa(f);if(c==f)return!0;if(Hc){var g=_.Gc(c),h=_.Gc(f);if(g||h){if(g)a=c;else if("string"===typeof c)a=Daa(c);else return!1;if(!h)if("string"===typeof f)f=Daa(f);else return!1;if(a.length!==f.length)return!1;for(h=0;h<a.length;h++)if(a[h]!==f[h])return!1;return!0}}if(c instanceof _.vd)return Vaa(c,f instanceof _.vd?f:Waa(c,d,e,f));if(f instanceof _.vd)return Vaa(f,Waa(f,a,b,c));if(null==c&&Array.isArray(f)&&f&&_.Rc(f)&1&&!f.length||null==f&&Array.isArray(c)&&
# c&&_.Rc(c)&1&&!c.length)return!0;if(!_.Ma(c)||!_.Ma(f))return"number"===typeof c&&isNaN(c)||"number"===typeof f&&isNaN(f)?String(c)==String(f):!1;if(c.constructor!=f.constructor)return!1;if(c.constructor===Array){h=c;b=a=void 0;c=Math.max(h.length,f.length);for(d=0;d<c;d++)if(e=h[d],g=f[d],e&&e.constructor==Object&&(a=e,e=void 0),g&&g.constructor==Object&&(b=g,g=void 0),!Raa(h,d,e,f,d,g))return!1;return a||b?(a=a||{},b=b||{},Saa(a,b)):!0}if(c.constructor===Object)return Saa(c,f);throw Error("Y");
# };_.Uaa=function(a,b){return Raa(void 0,void 0,a,void 0,void 0,b)};Yaa=function(a){switch(typeof a){case "number":return isFinite(a)?a:String(a);case "object":if(a&&!Array.isArray(a)){if(_.Gc(a))return _.wd(a);if(a instanceof _.od){var b=a.tb;return null==b?"":"string"===typeof b?b:a.tb=_.wd(b)}if(a instanceof _.vd)return Xaa(a)}}return a};Zaa=function(a,b){b.ka&&(a.ka=b.ka.slice())};
# _.yd=function(a,b,c,d){if(null!=a){if(Array.isArray(a))a=_.xd(a,b,c,void 0!==d);else if(nd(a)){var e={},f;for(f in a)e[f]=_.yd(a[f],b,c,d);a=e}else a=b(a,d);return a}};_.xd=function(a,b,c,d){d=d?!!(_.Rc(a)&16):void 0;var e=Array.prototype.slice.call(a);c(a,e);for(a=0;a<e.length;a++)e[a]=_.yd(e[a],b,c,d);return e};bba=function(a){return _.yd(a,$aa,aba)};$aa=function(a){return a.YR===sd?a.toJSON():a instanceof _.vd?Xaa(a,bba):Yaa(a)};cba=function(a){return _.yd(a,_.zd,aba)};
# _.zd=function(a){if(!a)return a;if("object"===typeof a){if(_.Gc(a))return new Uint8Array(a);if(a instanceof _.vd)return a.size?ud(a,_.hd(_.Ad(a,cba))):[];if(a.YR===sd)return a.clone()}return a};aba=function(){};_.Cd=function(a,b,c,d){var e=_.x(a,b,d);Array.isArray(e)||(e=Bd);var f=_.Rc(e);f&1||Uc(e);_.md(a)?(f&2||_.fd(e),c&1||Object.freeze(e)):e===Bd||!(c&1&&c&2)&&f&2?(e=Uc(Array.prototype.slice.call(e)),_.y(a,b,e,d)):!(c&2)&&f&16&&_.id(e);return e};
# _.Dd=function(a,b){var c=_.Cd(a,b,1,!1);if(c.length&&!(_.Rc(c)&4)){Object.isFrozen(c)&&(c=Uc(c.slice()),_.y(a,b,c,!1,!0));for(var d=b=0;b<c.length;b++){var e=c[b];null!=e&&(c[d++]=e)}d<b&&(c.length=d);Lc(c,5)}_.md(a)&&!Object.isFrozen(c)&&(_.fd(c),Object.freeze(c));return c};_.Gd=function(a,b,c,d){_.Ed(a);c!==d?_.y(a,b,c):_.Fd(a,b);return a};_.Hd=function(a,b,c){return _.Gd(a,b,c,"")};_.Id=function(a,b){return null==a?b:a};dba=function(a){Array.isArray(a)&&_.fd(a);return a};
# eba=function(a,b,c,d,e,f){(a=a.wj&&a.wj[c])?(e=f.DX?Uc(a.slice()):a,_.Jd(b,c,e)):(null!=d?Hc&&d instanceof Uint8Array?e=Iaa(d):d instanceof _.vd?e=d.j.size?ud(d,_.Ad(d,(e||d instanceof _.vd&&d.o&2)&&d.ha?dba:void 0)):[]:(Array.isArray(d)&&(e?_.fd(d):d&&_.Rc(d)&1&&f.DX?(e=Array.prototype.slice.call(d),_.kd(d,e),d=e):_.id(d)),e=d):e=void 0,_.y(b,c,e))};gba=function(a){if(_.ed(a)&&Object.isFrozen(a))return a;var b=_.Kd(a,fba);Haa(a,b);Object.freeze(b);return b};
# Ld=function(a,b){if(null!=a){if(Hc&&a instanceof Uint8Array)return Iaa(a);if(Array.isArray(a)){if(_.ed(a))return a;b&&(b=_.Rc(a),b=!(b&32)&&(!!(b&16)||0===b));return b?(_.fd(a),a):_.xd(a,Ld,Haa)}return a.YR===sd?fba(a):a instanceof _.vd?ud(a,_.fd(_.Ad(a,Ld))):a}};fba=function(a){if(_.md(a))return a;a=_.hba(a);_.fd(a.Cf);return a};
# _.hba=function(a){var b=new a.constructor;Zaa(b,a);for(var c=a.Cf,d=!!(_.Rc(c)&16),e=0;e<c.length;e++){var f=c[e];if(e===c.length-1&&nd(f))for(var g in f){var h=+g;if(Number.isNaN(h))iba(b)[h]=f[h];else{var l=f[g],n=a.wj&&a.wj[h];n?_.Jd(b,h,gba(n),!0):_.y(b,h,Ld(l,d),!0)}}else h=e-a.Pv,(l=a.wj&&a.wj[h])?_.Jd(b,h,gba(l),!1):_.y(b,h,Ld(f,d),!1)}return b};
# _.td=function(a){if(!_.md(a))return a;var b={DX:!0},c=_.md(a);if(c&&!b.DX)throw Error("Z");c||_.id(a.Cf);var d=new a.constructor;Zaa(d,a);for(var e=a.Cf,f=0;f<e.length;f++){var g=e[f];if(f===e.length-1&&nd(g))for(var h in g){var l=+h;Number.isNaN(l)?iba(d)[h]=g[h]:eba(a,d,l,g[h],c,b)}else eba(a,d,f-a.Pv,g,c,b)}d.dR=a;return d};
# _.kba=function(a,b){var c=a.Cf.length,d=c-1;if(c&&(c=a.Cf[d],nd(c))){a.ll=c;b=Object.keys(c);0<b.length&&_.jba(b,isNaN)?a.nx=Number.MAX_VALUE:a.nx=d-a.Pv;return}void 0!==b&&-1<b?(a.nx=Math.max(b,d+1-a.Pv),a.ll=void 0):a.nx=Number.MAX_VALUE};lba=function(a,b){return Yaa(b)};
# _.mba=function(a,b){Zaa(a,b);var c=b.wj;if(c){b=b.ll;for(var d in c){var e=c[d];if(e){var f=!(!b||!b[d]),g=+d;if(Array.isArray(e)){if(e.length)for(f=_.Md(a,e[0].constructor,g,f),g=0;g<Math.min(f.length,e.length);g++)_.mba(f[g],e[g])}else throw Error("ba`"+_.nba(e)+"`"+e);}}}};
# _.oba=function(a){if("string"===typeof a)return{buffer:Caa(a),Bk:!1};if(Array.isArray(a))return{buffer:new Uint8Array(a),Bk:!1};if(a.constructor===Uint8Array)return{buffer:a,Bk:!1};if(a.constructor===ArrayBuffer)return{buffer:new Uint8Array(a),Bk:!1};if(a.constructor===_.od){Eaa(_.Jc);var b=Daa(a.tb);return{buffer:(null==b?b:a.tb=b)||_.Nd||(_.Nd=new Uint8Array(0)),Bk:!0}}if(a instanceof Uint8Array)return{buffer:new Uint8Array(a.buffer,a.byteOffset,a.byteLength),Bk:!1};throw Error("ka");};
# _.Pd=function(a,b){return new _.Od(a,b)};pba=function(a){var b=this.Ub,c=this.rk;return this.Iu?_.Md(a,b,c,!0):_.z(a,b,c,!0)};qba=function(a,b){var c=this.rk;return this.Iu?_.Jd(a,c,b,!0):_.Qd(a,c,b,!0)};_.rba=function(a,b){b=void 0===b?window:b;return(b=b.WIZ_global_data)&&a in b?b[a]:null};_.Sd=function(a){var b=void 0===b?window:b;return new _.Rd(a,_.rba(a,b))};
# _.tba=function(a){if(!sba){a:{var b=document.createElement("a");try{b.href=a}catch(c){a=void 0;break a}a=b.protocol;a=":"===a||""===a?"https:":a}return a}try{b=new URL(a)}catch(c){return"https:"}return b.protocol};_.Ud=function(a){a instanceof _.ac?a=_.mc(a):a="javascript:"!==_.tba(a)?a:void 0;return a};_.Wd=function(a,b){if(void 0!==a.tagName){if("script"===a.tagName.toLowerCase())throw Error("Aa");if("style"===a.tagName.toLowerCase())throw Error("Ba");}a.innerHTML=_.Vd(b)};
# _.uba=function(a,b,c,d){if(0===a.length)throw Error("ya");a=a.map(function(f){if(f instanceof _.Xd)f=f.j;else throw Error("H");return f});var e=c.toLowerCase();if(a.every(function(f){return 0!==e.indexOf(f)}))throw Error("za`"+c);b.setAttribute(c,d)};_.vba=function(a){var b,c,d=null==(c=(b=(a.ownerDocument&&a.ownerDocument.defaultView||window).document).querySelector)?void 0:c.call(b,"script[nonce]");(b=d?d.nonce||d.getAttribute("nonce")||"":"")&&a.setAttribute("nonce",b)};
# _.Zd=function(a,b){a.src=_.Yd(b);_.vba(a)};_.$d=function(a){return a.pathname.replace(wba,"/")};_.ae=function(a){a=_.$d(a).match(_.xba);return(null==a?0:a.length)?a[0]:null};
# _.zba=function(a){var b=_.ae(a),c="";if("/search"===b)c=_.be(new _.ce(a.href),"q")||"";else if("/stories"===b)c="Full Coverage";else if("/foryou"===b)c="For You";else if("/topstories"===b)c="Top Stories";else if("/topics"===b)c="Topic";else if("/publications"===b)c="News Edition";else if("/settings"===b)c="Settings";else if("/covid19"===b)c="Covid Map";else if("/showcase"===b)c="News Showcase";else if("/articles"===b)c="Article Reading";else if("/issues"===b)c="Issues";else if("/home"===b)c="Home";
# else if("/"===b)c="Root";else if("/my"===b){a=_.$d(a);var d;(null==(d=a.match(yba))?0:d.length)?c="Following":a.includes("my/locations")&&(c="My Locations")}return c};_.ee=function(a){if(!_.de.has("startup"))throw Error("Fa`startup");_.Aba.has("startup")?a.apply():_.Bba.startup.push(a)};_.fe=function(a,b){b.hasOwnProperty("displayName")||(b.displayName=a);b[Cba]=a};Dba=function(a){a=a[Cba];return a instanceof _.ge?a:null};ie=function(a){he.push(a)};_.Eba=function(a){_.Wa(he,function(b){_.je(b,a)})};
# Fba=function(){return _.Kd(he,function(a){return a.Iq})};_.ke=function(a,b){var c=_.Gba[a];c||(c=_.Gba[a]=[]);c.push(b)};_.Iba=function(){return lb()||_.db("iPod")?4:_.db("iPad")?5:_.kb()?Hba()?3:2:_.le()?1:0};me=function(a,b){Jba(b).add(a)};ne=function(a){return new _.Kba(function(b){return b.substr(0,a.length+1).toLowerCase()===a+":"})};Lba=function(a){var b=new Map,c;for(c in a)b.set(a[c].Ra,a[c].sq);return b};
# Mba=function(){var a=void 0;void 0===a&&(a={});var b,c;return{q9:null!=(b=a.q9)?b:null,Ffa:null!=(c=a.Ffa)?c:!1}};
# Wba=function(){if(!_.Nba){var a=Mba(),b=_.oe(_.Sd("GASP4"),Oba,-1),c=new _.pe,d=_.be(new _.ce(window.location),"ceid");d&&_.Hd(c.o,2,d);(d=_.Sd("mc2ogb"))&&d.Rc()&&(d=_.oe(d,Pba,0),Qba(c,Rba(d)));(d=_.Sd("RXFAJc"))&&d.Rc()&&(d=_.oe(d,Sba,0),d=Tba(d),_.Qd(c.o,10,d));_.Uba(c,_.zba(window.location));var e;Vba(b,new _.re(!1,!0),a.Ffa?void 0:140,{VM:c,transport:null!=(e=a.q9)?e:void 0});_.ke(_.se,function(f){var g=_.Sd("hbSvMb"),h=[];g&&g.Rc()&&(h=g.o().map(function(q){return q.number()}));g=_.Sd("ysqeUe");
# var l=[];if(g&&g.Rc()){var n,p;l=null!=(p=null==(n=_.te(g,_.ue))?void 0:n.RP())?p:[]}h=Array.from(new Set(h.concat(l)));f.mb(_.ve(h))})}};_.Xba=function(a,b){if(!b&&a.hasAttribute("jsshadow"))return null;for(b=0;a=_.we(a);){if(a.hasAttribute("jsslot"))b+=1;else if(a.hasAttribute("jsshadow")&&0<b){--b;continue}if(0>=b)return a}return null};_.we=function(a){return a?_.xe(a)?_.xe(a):a.parentNode&&11===a.parentNode.nodeType?a.parentNode.host:_.ye(a):null};
# _.ze=function(a,b,c,d){for(c||(a=_.Xba(a,d));a;){if(b(a))return a;a=_.Xba(a,d)}return null};_.Yba=function(a){var b;_.ze(a,function(c){return _.xe(c)?(b=_.xe(c),!0):!1},!0);return b||a};Zba=function(a){return _.Ae.has(a)?_.Ae.get(a):[]};_.$ba=function(a){"__jsaction"in a&&delete a.__jsaction};
# aca=function(){var a,b,c;_.C(function(d){if(1==d.j)return navigator.geolocation&&navigator.permissions&&(null==(a=window.document.body)?0:null==(b=a.classList)?0:b.add)?_.D(d,navigator.permissions.query({name:"geolocation"}),2):d.return();c=d.o;"granted"===c.state&&window.document.body.classList.add("pMMv8d");_.Be(d)})};_.De=function(a){return _.Ma(a)&&void 0!==a.Cc&&a.Cc instanceof _.Ce&&void 0!==a.Tb&&(void 0===a.jd||a.jd instanceof _.F)?!0:!1};
# bca=function(a){var b=a.jxb;_.De(a)&&(b=a.metadata?!a.metadata.fatal:void 0);return b};cca=function(a,b){if(!a)return _.Ee();var c=a.Jr;return _.De(a)&&(c=a.metadata?a.metadata.Jr:void 0,a.metadata&&a.metadata.Roa)?_.Fe(b,{service:{lw:_.Ge}}).then(function(d){d=d.service.lw;for(var e=_.He(a.metadata.Roa),f=e.next();!f.done;f=e.next())f=f.value,d.isEnabled(f.lvb)&&(c=f.Jr);return c}):_.Ee(c)};
# eca=function(a,b,c){return cca(a,c).then(function(d){if(void 0==d||0>d)return b;var e=!1;b.then(function(){e=!0},function(){});d=_.Ie(d,_.Ee(null));a.metadata&&(a.metadata.sba=!1);d.then(function(){a.metadata&&(a.metadata.sba=!e)});return _.dca([b,d])})};fca=function(a,b){return bca(a)?b.Bh(function(){return _.Ee(null)}):b};
# kca=function(a,b){return _.De(a)&&a.metadata&&a.metadata.lDa?b.then(function(c){if(!c&&a.metadata&&a.metadata.sba){c=new gca;var d=new _.Je;_.y(hca(d,"wiz.data.clients.WizDataTimeoutError","type.googleapis.com"),2,c);return _.ica(_.jca(new _.Ke,2),[d])}return null},function(c){return c instanceof _.Le?c.status:null}):b};mca=function(a,b){var c=_.Fe(a,{service:{hGa:_.lca}});return _.zb(b,function(d){return c.then(function(e){return e.service.hGa.o(d)})})};_.Me=function(){};
# nca=function(a){_.Oe(null,a)};qca=function(){var a={};a.location=document.location.toString();if(oca())try{a["top.location"]=top.location.toString()}catch(c){a["top.location"]="[external]"}else a["top.location"]="[external]";for(var b in pca)try{a[b]=pca[b].call()}catch(c){a[b]="[error] "+c.message}return a};
# Aca=function(a){rca.init();a&&(a=new Pe(a,void 0,!0),a=new sca(a),_.tca.j=a,uca(a));var b=null;a=function(c){_.ha.$googDebugFname&&c&&c.message&&!c.fileName&&(c.message+=" in "+_.ha.$googDebugFname);b?c&&c.message&&(c.message+=" [Possibly caused by: "+b+"]"):b=String(c);_.Oe(null,c)};_.Qe("_DumpException",a);_.Qe("_B_err",a);_.Wa([_.ha].concat([]),_.Re(vca,_.Re(wca,!0),!0));28<=_.jb("Chromium")||14<=_.jb("Firefox")||11<=_.jb("Internet Explorer")||_.jb("Safari");9>=_.jb("Internet Explorer")||(a=new Se(nca),
# a.o=!0,a.j=!0,xca(a),Te(a,"setTimeout"),Te(a,"setInterval"),yca(a),zca(a),_.tca.o=a)};wca=function(a,b){_.bb(b.message,"Error in protected function: ")||(b.error&&b.error.stack?_.Oe(null,b.error):a||_.Oe(null,b))};_.Ue=function(a,b){a.__soy_skip_handler=b};Ve=function(){};Cca=function(a,b,c){a=a.style;if("string"===typeof c)a.cssText=c;else{a.cssText="";for(var d in c)Bca.call(c,d)&&(b=c[d],0<=d.indexOf("-")?a.setProperty(d,b):a[d]=b)}};
# Dca=function(a,b,c){var d=typeof c;"object"===d||"function"===d?a[b]=c:null==c?a.removeAttribute(b):(d=0===b.lastIndexOf("xml:",0)?"http://www.w3.org/XML/1998/namespace":0===b.lastIndexOf("xlink:",0)?"http://www.w3.org/1999/xlink":null)?a.setAttributeNS(d,b,c):a.setAttribute(b,c)};_.Eca=function(){var a=new Ve;a.__default=Dca;a.style=Cca;return a};We=function(a){a=a.__soy;a.OEa();return a};Gca=function(a){for(;a&&!a.L7&&!Fca(a);)a=a.parentElement;return{element:a,Aba:a.L7}};
# Ica=function(){_.Xe({soy:function(a){var b=a.wa?a.wa().el():a.oq();var c=b.__soy?We(b):null;if(c)return _.Ee(c);var d=Gca(b),e=d.element;e.bW||(e.bW=new Set);var f=e.bW;c=new Set;for(var g=_.He(f),h=g.next();!h.done;h=g.next())h=h.value,_.Ye(b,h)&&c.add(h);c.size||(f.add(b),b.__soy_tagged_for_skip=!0);a=d.Aba?d.Aba.then(function(){f.clear();var l=b.__soy?We(b):null;if(l)return l;e.__soy.render();return We(b)}):_.Ze([a.nj(_.Hca,d.element),_.Fe(a,{service:{xS:_.$e}})]).then(function(l){var n=l[1].service.xS;
# return l[0].xsa().then(function(p){d.element.getAttribute("jsrenderer");f.clear();e.__incrementalDOMData||n.tva(e,p.Mc,p.args);if((!b.__soy||!We(b))&&e.__incrementalDOMData){p="Hydration source "+(document.body.contains(e)?"in dom":"not in dom")+";";var q="El source "+(document.body.contains(b)?"in dom":"not in dom");_.ia(Error("gb`"+p+"`"+q+"`"+(b.getAttribute("jscontroller")||b.getAttribute("jsmodel"))));return null}return We(b)})});b.bW=c;b.L7=a;return a.then(function(l){return l})}})};Jca=function(){};
# Lca=function(a){var b=this.getAttribute(a);Element.prototype.setAttribute.apply(this,arguments);var c=this.getAttribute(a);_.af(this,Kca,{name:a,bF:c,kCa:b},!1)};Mca=function(a){var b=this.getAttribute(a);Element.prototype.removeAttribute.apply(this,arguments);_.af(this,Kca,{name:a,bF:null,kCa:b},!1)};Nca=function(){return!!(window.performance&&window.performance.mark&&window.performance.measure&&window.performance.clearMeasures&&window.performance.clearMarks)};
# ...
# c),_.S(a.F,"gb_Wd",c));if(a.H&&!a.oa){e=a.H.J();var f=!a.ha;_.S(e,"gb_za",!f);f&&dj(a,a.O)}a.j&&(a.j.isVisible("menu")||a.j.isVisible("back"))&&!Ji(a.j)&&(a.Ha=a.j.Hb());e=_.Mg(xi);_.Me(a.A,e);_.M(a.A,b);if(a.ma&&null!=a.G)if("gb_Mc"!=b)_.$g(a.G,"min-width",""),_.$g(a.F,"min-width","");else{f=_.hh(a.G).width;var g=_.hh(a.F).width;f=Math.max(f,g);_.$g(a.G,"min-width",f+"px");_.$g(a.F,"min-width",f+"px")}c?a.V||(a.V=!0,gj(a,a.V)):(a.V=!1,a.Ke());null!=a.D&&(_.S(a.D,"gb_Ke",!c&&!d),_.S(a.D,"gb_Je",c||
# d));a.j&&(c=a.j.j,_.Me(c,e),_.M(c,b),Ji(a.j)?_.R("gb_6d").appendChild(c):a.A.appendChild(c),a.j.isVisible("menu")||a.j.isVisible("back"))&&(b=!Ji(a.j),c=a.j.Hb(),b&&!c&&a.Ha?a.j.open():!b&&c&&a.j.close());mj(a)},dj=function(a,b){var c=_.R("gb_yc",a.H.J());_.S(c,"gb_za",!b);a=_.R("gb_4d",a.H.J());null!=a&&_.S(a,"gb_ie",!b)},Zi=function(a,b,c){var d=320,e=_.Oa(_.D(a.o,29),0);0<e&&(d=e);e=d+2*Math.max(b,c);b=d+b+c;return e!=b&&a.ma?[{id:1,max:b},{id:2,max:e},{id:3}]:[{id:1,max:b},{id:3}]},Xi=function(a,
# b){if(a=_.R(b?"gb_pe":"gb_qe",a.A)){var c=a.offsetWidth;_.ub(a.children,function(d){_.L(d,"gb_za")&&(c-=d.offsetWidth)});return c}return 0},nj=function(a){return function(){a.click()}},lj=function(a){var b=_.R("gb_pe",a.A),c=_.R("gb_qe",a.A),d=[];b&&_.ub(b.children,function(e){d.push(e)});_.t(_.E(a.o,7),!1)&&(a=_.R("gb_De",a.D))&&(a=_.R("gb_mf",a),a.j=!0,d.push(a));c&&_.ub(c.children,function(e){d.push(e)});return d};
# U.prototype.Ba=function(){if(this.va&&this.C){var a=lj(this),b=!1;a=_.vb(a,function(f){b=b||_.L(f,"gb_se");return _.L(f,"gb_8c")||_.L(f,"gb_vf")||_.L(f,"gb_mf")});var c=this.Ya.j.Zd,d=!1;if(a.length>c||b)d=!0,c--;var e=a.length-c;if(d!=!_.L(this.Ga,"gb_za")||e!=this.U.children){_.S(this.Ga,"gb_za",!d);if(d)for(;this.U.firstChild;)this.U.removeChild(this.U.firstChild);oj(this,a,c);d?this.T.B(document.body,pj,this.Xa,!0,this):this.T.Ja(document.body,pj,this.Xa,!1,this)}}};
# var oj=function(a,b,c){b=_.vb(b,function(f){return _.L(f,"gb_se")?(qj(this,f),!1):!0},a);for(var d=0;d<b.length;d++){var e=b[d];d>=c?qj(a,e):_.Le(e,"gb_za")}},qj=function(a,b){_.M(b,"gb_za");var c=_.ze("LI");_.Ke(c,["gb_ze","gb_Tc","gb_Zc"]);c.tabIndex=0;_.Ch(a.T,c,nj(b));var d=_.Q("A","gb_Vc");c.appendChild(d);var e=_.Q("SPAN","gb_Wc");d.appendChild(e);d=b.j?b.getAttribute("aria-label"):b.title;_.Ug(e,d);d=!1;_.L(b,"gb_vf")&&(d=!0);var f,g=b.children[0];d?f=g.children[0].children[0].src:b.j?f="https://www.gstatic.com/images/icons/material/system/1x/search_black_24dp.png":
# f=g.src;a.B=_.Q("IMG");_.Ke(a.B,["gb_Xc","gb_Ae"]);a.B.setAttribute("src",f);e.parentNode&&e.parentNode.insertBefore(a.B,e);a.U.appendChild(c)};U.prototype.Xa=function(a){!_.L(this.Ad,"gb_za")&&a.target instanceof Node&&("keydown"==a.type?27==a.keyCode&&(a.preventDefault(),a.stopPropagation(),_.M(this.Ad,"gb_za"),this.J().focus()):_.Ag(this.Ad,a.target)||("touchstart"==a.type&&(a.preventDefault(),a.stopPropagation()),_.M(this.Ad,"gb_za")))};
# U.prototype.Kb=function(){cj(this,this.L.j);this.j&&_.rj(this,this.j.Hb(),!1);this.dispatchEvent("ffc")};_.rj=function(a,b,c){a.j&&(Ji(a.j)&&(c=b=!1),a=document.body,_.S(a,"gb_ne",b),_.S(a,"gb_me",c))};U.prototype.Vb=function(){_.rj(this,!0,!0)};U.prototype.Lb=function(){_.rj(this,!1,!0)};U.prototype.Wb=function(){var a=Ji(this.j),b=this.j.j;a?_.R("gb_6d").appendChild(b):this.A.appendChild(b)};_.kj=function(a){return!!a.j&&_.L(a.F,"gb_Wd")};
# U.prototype.M=function(a){var b=!1;switch(a){case "back":this.S=!0;Li(this.j);Ki(this.j,"back");b=!0;break;case "close":this.S=!0;Li(this.j);Ki(this.j,"close");b=!0;break;case "default":this.S=!1;jj(this,this.L.j)||this.Ac?(this.j&&!this.j.isVisible("menu")&&(Li(this.j),Ki(this.j,"menu")),b=!0):(this.j&&this.j.isVisible("back")&&Li(this.j),this.j&&this.j.isVisible("menu")?(a=this.j,a.close(),_.M(a.J(),"gb_za"),!_.L(a.X,"gb_za")&&_.Le(a.J(),"gb_Ec")):(a=_.R("gb_zc",this.A))&&_.M(a,"gb_za"),b=!1);break;
# case "none":this.S=!0,Li(this.j),b=!1}null!=this.G&&_.S(this.G,"gb_3c",b)};var jj=function(a,b){var c=_.t(_.E(a.o,5),!1),d=_.t(_.E(a.o,2),!1);return!(_.t(_.E(a.o,10),!1)||a.oa||_.t(_.E(a.o,44),!1))&&d&&("gb_pa"==b||"gb_Pd"==b&&(c||a.ha))};U.prototype.yb=function(){return this.A.offsetHeight};var mj=function(a){var b=a.A.offsetHeight+"px";a.La!=b&&(a.La=b,a.rb&&(a.rb.style.height=b),a.dispatchEvent("resize"))};U.prototype.Cc=function(){this.N&&mj(this)};
# U.prototype.Jb=function(){if(!this.N){var a=_.ze("DIV");_.Ke(a,["gb_Sd","gb_2d"]);sj(a,ej(this));a.style.backgroundColor=this.A.style.backgroundColor;this.ka.push(a);var b=this.C;b.parentNode&&b.parentNode.insertBefore(a,b.nextSibling);this.N=a}return this.N};U.prototype.Ec=function(){_.zg(this.N);this.N=null;mj(this)};_.tj=function(a,b){a.C?a.C.appendChild(b):a.F?a.F.appendChild(b):a.P.log(Error("fa"))};
# U.prototype.ob=function(a){2==a&&(a=0);for(var b=0;b<this.ka.length;b++)sj(this.ka[b],a);fj(this,a)};var fj=function(a,b){if(a.H){if(2==b){b=_.u(_.D(a.o,24),"");var c=_.u(_.D(a.o,27),"")}else 1==b?(b=_.u(_.D(a.o,23),""),c=_.u(_.D(a.o,26),"")):(b=_.u(_.D(a.o,22),""),c=_.u(_.D(a.o,25),""));""==b&&""==c||ii(a.H,b,c)}},ej=function(a){a=a.ka[0];return a.classList.contains("gb_Ac")?1:a.classList.contains("gb_3d")?2:0},sj=function(a,b){_.Me(a,["gb_3d","gb_Ac"]);1==b?_.M(a,"gb_Ac"):2==b&&_.M(a,"gb_3d")};
# U.prototype.nb=function(a){this.A.style.backgroundColor=a};U.prototype.Eb=function(){return this.A.style.backgroundColor};U.prototype.ya=function(){var a=_.Se("dd");_.Yh(a)&&_.Yh(a).Hd(!1);a.nf(null)};U.prototype.Re=function(a){Yi(this,a-8-10);ij(this)};var Yi=function(a,b){null==a.D?a.P.log(Error("ga")):a.ma?a.P.log(Error("ha")):a.mb=0>b?0:b},ij=function(a){null!=a.G&&("gb_pa"==a.L.j?_.$g(a.G,"min-width",""):null!=a.mb&&_.$g(a.G,"min-width",a.mb+"px"))};
# U.prototype.We=function(a){_.S(_.R("gb_sc",this.C),"gb_za",!a)};U.prototype.te=function(a){a&&(_.$h(_.R("gb_8d"),a),_.I.j().o.then(function(b){return void b.Dd(a)}))};var pj="click mousedown scroll touchstart wheel keydown".split(" "),$i=[{id:"gb_pa",max:599},{id:"gb_Pd",max:1023},{id:"gb_Mc"}],aj=[{id:{id:"oneProductControl",Zd:1},max:320},{id:{id:"twoProductControl",Zd:2},max:360},{id:{id:"threeProductControl",Zd:3},max:410},{id:Wi}];
# var uj;_.O.prototype.za=_.qe(function(a,b,c,d,e){return a.call(this,b,_.qe(fi,c),d,e)},_.O.prototype.listen);_.O.prototype.zb=_.O.prototype.ti;var vj=_.R("gb_oa");
# if(null==vj)uj=null;else{var wj=_.F(_.Vd,_.Re,6)||new _.Re,xj=new U(vj,wj,_.K,_.R("gb_Od"));_.A("gbar.P",U);U.prototype.pa=U.prototype.yb;U.prototype.pb=U.prototype.ak;U.prototype.pc=U.prototype.ob;U.prototype.pd=U.prototype.nb;U.prototype.pe=U.prototype.Jb;U.prototype.pf=U.prototype.Cc;U.prototype.pg=U.prototype.Ec;U.prototype.ph=U.prototype.Wg;U.prototype.pi=U.prototype.ya;U.prototype.pj=U.prototype.Re;U.prototype.pk=U.prototype.We;U.prototype.pl=U.prototype.te;U.prototype.pm=U.prototype.M;U.prototype.pn=
# U.prototype.Eb;U.prototype.po=U.prototype.Yj;U.prototype.pp=U.prototype.Wa;_.I.j().B.resolve(xj);uj=xj}_.yj=uj;
#
# }catch(e){_._DumpException(e)}
# try{
# var zj=document.querySelector(".gb_Ma .gb_A"),Aj=document.querySelector("#gb.gb_Jc");zj&&!Aj&&_.ie(_.$d,zj,"click");
#
# }catch(e){_._DumpException(e)}
# try{
# (function(){for(var a=document.querySelectorAll(".gb_uc"),b=0;b<a.length;b++)_.ie(_.$d,a[b],"click");_.I.j().B.then(function(c){if(c){var d=_.R("gb_sc",c.C);d&&(d=new _.Nh(d,_.K,_.Zd),c.Xj(d))}})})();
#
# }catch(e){_._DumpException(e)}
# })(this.gbar_);
# // Google Inc.
# </script><c-wiz c-wiz="" class="zQTmif SSPGKf" data-node-index="0;0" data-ogpc="" data-p='%.@."microsoft",[["en-US","US",["SPORTS_FULL_COVERAGE","WEB_TEST_1_0_0"],null,[],1,1,"US:en",null,null,null,null,null,null,null,false],"en-US","US",true,[2,4,27],1,true,"480950095",false,false,null,false],1]' jsdata="deferred-i1" jslog="88503; 3:W251bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLDE0MSxudWxsLG51bGwsbnVsbCwzN10=; track:vis" jsmodel="hc6Ubd" jsname="a9kxte" jsrenderer="vBVNjc" view=""><div class="T4LgNb" jsname="a9kxte"><div class="VjFXz"></div><div class="FVeGwb CVnAc Haq2Hf bWfURe" data-n-ca-it="microsoft" data-n-et="710" jsaction="rcuQ6b:npT2md;kfsncb:QnC63e;" jscontroller="BeJYtf" jsmodel="FSc7tf" jsname="G2oM1c"><div data-n-pt="3" jsname="ReIlqe"></div><div class="ajwQHc BL5WZb RELBvb"><div class="tsldL Oc0wGc RELBvb"><main class="HKt8rc CGNRMc" jslog="94187; 3:W251bGwsbnVsbCxudWxsLG51bGwsbnVsbCxudWxsLDE0MSxudWxsLG51bGwsbnVsbCwzN10=" jsname="fjw8sb"><c-wiz c-wiz="" class="FffXzd" data-n-ca-it="microsoft" data-n-et="406" data-n-ham="true" data-n-q="microsoft" data-node-index="0;0" data-p='%.@."microsoft",[["en-US","US",["SPORTS_FULL_COVERAGE","WEB_TEST_1_0_0"],null,[],1,1,"US:en",null,null,null,null,null,null,null,false],"en-US","US",true,[2,4,27],1,true,"480950095",false,false,null,false],1]' jsaction="rcuQ6b:npT2md;" jscontroller="o2EnYc" jsdata="deferred-i2" jsmodel="hc6Ubd GITtrd hT8rr" jsrenderer="vBVNjc" view=""><div class="lBwEZb BL5WZb GndZbb" data-n-et="200" data-n-ham="true" jscontroller="SpTAFc" jsdata="tbf4if;ui|124+fd016f4a-2ab4-415d-9cd8-00d36e5eb196,ui|124+9f4e4f86-c810-4d65-a3e4-6e3a3fdb9e3d;3" jsmodel="dPwZPd hT8rr" jsname="esK7Lc"><div class="NiLAwe mi8Lec gAl5If jVwmLb Oc0wGc R7GTQ keNKEd j7vNaf nID9nc" data-n-cvid="i3" data-n-et="250" data-n-ham="true" jsaction="JIbuQc:h5M12e;rcuQ6b:npT2md;" jscontroller="MRcHif" jsdata="tbf4if;ui|124+705455d5-c8ae-41bb-9812-ec94e6441881,ui|124+f2f7f050-ed99-4b64-a4ab-889b21177e8d;4" jslog="130458; 3:W251bGwsbnVsbCxudWxsLG51bGwsImNoYW5uZWxfc3RvcnlfMzYwOkNBQXFOZ2dLSWpCRFFrbFRTR3B2U21NelVuWmpibXQwVFhwWmQxTm9SVXRFZDJscWFqUlVPVUpTU0ZjeVN6QnZUR3h4ZUVGVFowRlFBUSIsbnVsbCwxNDEsbnVsbCxudWxsLG51bGwsMzcsbnVsbCxudWxsLFtbW251bGwsIm1pY3Jvc29mdCJdXSwxLDRdXQ==; track:vis; index:0" jsmodel="dPwZPd;hT8rr"><div class="DBQmFf NclIid BL5WZb Oc0wGc xP6mwf j7vNaf"><div class="xrnccd F6Welf R7GTQ keNKEd j7vNaf" jsname="gKDw6b"><a aria-labelledby="i4" href="./articles/CBMiWWh0dHBzOi8vd3d3LnRodXJyb3R0LmNvbS9jbG91ZC9taWNyb3NvZnQtMzY1LzI3NDc4Mi9uby1taWNyb3NvZnQtb2ZmaWNlLWlzLW5vdC1nb2luZy1hd2F50gEA?hl=en-US&amp;gl=US&amp;ceid=US%3Aen" tabindex="-1" target="_blank"><figure class="AZtY5d fvuwob d7hoq" jsaction="error:HLDri" jscontroller="dAR81"><img alt="" aria-label="Image" class="tvs3Id QwxBBf" id="i4" jslog="131347" loading="lazy" src="https://lh3.googleusercontent.com/proxy/7zXLoZcpuxWgu6JjWoxGcy2RsggopKWCHpX2yx2SRXr-1m120fy7H_IVtsA6Wshg_WBuKwH6Y4qrBxoAAfnLvUAdPbAk95MJ8U_li9rdQd5fOWHR4uHyZIwZXlXl6IdcLrJ24uL_UaO2MAzy0YxT0KdT=s0-w100-h100-dcjTKGaCEF" srcset="https://lh3.googleusercontent.com/proxy/7zXLoZcpuxWgu6JjWoxGcy2RsggopKWCHpX2yx2SRXr-1m120fy7H_IVtsA6Wshg_WBuKwH6Y4qrBxoAAfnLvUAdPbAk95MJ8U_li9rdQd5fOWHR4uHyZIwZXlXl6IdcLrJ24uL_UaO2MAzy0YxT0KdT=s0-w100-h100-dcjTKGaCEF 1x, https://lh3.googleusercontent.com/proxy/7zXLoZcpuxWgu6JjWoxGcy2RsggopKWCHpX2yx2SRXr-1m120fy7H_IVtsA6Wshg_WBuKwH6Y4qrBxoAAfnLvUAdPbAk95MJ8U_li9rdQd5fOWHR4uHyZIwZXlXl6IdcLrJ24uL_UaO2MAzy0YxT0KdT=s0-w200-h200-dcjTKGaCEF 2x"/></figure></a><article class="MQsxIb xTewfe R7GTQ keNKEd j7vNaf Cc0Z5d EjqUne" data-kind="13" data-n-cvid="i5" data-n-et="107" data-n-ham="true" data-n-vlb="0" jsaction=";rcuQ6b:npT2md; click:KjsqPd;" jscontroller="HyhIue" jsdata="oM6qxc;CBMiWWh0dHBzOi8vd3d3LnRodXJyb3R0LmNvbS9jbG91ZC9taWNyb3NvZnQtMzY1LzI3NDc4Mi9uby1taWNyb3NvZnQtb2ZmaWNlLWlzLW5vdC1nb2luZy1hd2F50gEA;5" jslog="85008; 3:...; track:vis; index:0" jsmodel="a4N6Ae hT8rr" ve-visible="false"><a aria-hidden="true" class="VDXfz" href="./articles/CBMiWWh0dHBzOi8vd3 ...
# c.initAft=function(){f=0;e=Array.prototype.slice.call(document.getElementsByTagName("img")).filter(function(a){return!!a.getAttribute("data-iml")});[].forEach.call(document.getElementsByTagName("img"),function(a){try{_recordIsAboveFold(a)}catch(b){throw b.message=a.hasAttribute("data-iid")?b.message+"\nrecordIsAboveFold error for defer inlined image":b.message+("\nrecordIsAboveFold error for img element with <src: "+a.src+">"),b;}});if(0===d.length)c.onaft(f)};}).call(this);
# initAft()</script><script id="_ij" nonce="Wlqc5JcCHoITsfmOUUzf4w">window.IJ_values = ['\/\/www.google.com\/advanced_search?hl\x3den-US\x26fg\x3d1\x26q\x3dmicrosoft',[null,null,"",false,null,null,true,false],'0','www.google.com','https:\/\/news.google.com\/', null ,'boq_dotssplashserver_20221011.07_p1','news.google.com','US:en', 0.0 , 1.0 , 0.0 , null , null , null ,'','https:\/\/lh3.googleusercontent.com\/Sk9fLyVEoDk-5rONLR5ifRY3mmAmbeNSaM6mMLjLE-XeFLL1s4KXpzDFrRzD5Yl5xufCzbEyLow','CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSmxiaWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSmtaU2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnBkQ2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnFZU2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnJieWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSmhjaWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSm1jaWdBUAE,CAAqKAgKIiJDQkFTRXdvSkwyMHZNREZqY0hsNUVnWmxjeTAwTVRrb0FBUAE,CAAqJggKIiBDQkFTRWdvSkwyMHZNREZqY0hsNUVnVndkQzFRVkNnQVAB,CAAqJggKIiBDQkFTRWdvSkwyMHZNREZqY0hsNUVnVndkQzFDVWlnQVAB,CAAqJggKIiBDQkFTRWdvSkwyMHZNREZqY0hsNUVnVjZhQzFVVnlnQVAB,CAAqJggKIiBDQkFTRWdvSkwyMHZNREZqY0hsNUVnVjZhQzFJU3lnQVAB,CAAqKQgKIiNDQkFTRkFvSkwyMHZNREZqY0hsNUVnZDZhQzFJWVc1ektBQVAB,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnViQ2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSjBhQ2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnBaQ2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnlkU2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSjBjaWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSjFheWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSm9hU2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnVieWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnpkaWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSmpjeWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSndiQ2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSmliaWdBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSmxiQ2dBUAE,CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY0hsNUVnSnBkeWdBUAE,CAAqBwgKMJy5lwswj-KuAw,CAAqBwgKML6Ulwswt7yuAw,CAAqBwgKMLi6mgsw0sSyAw,CAAqBwgKMLH2lwswzJ-vAw,CAAqBwgKMMmAmAsw8qmvAw,CAAqBwgKMMPxlwsw5JqvAw,CAAqBwgKMMqAmAsw9KmvAw,CAAqBwgKMMT_lwsw7qivAw,CAAqBwgKMMX_lwsw76ivAw,CAAqBwgKMMy89Aows-naAg,CAAqBwgKMN30lwsw_J2vAw,CAAqBwgKMNDolwsw7ZGvAw,CAAqBwgKMIOemAswpbywAw,CAAqBwgKMNXelwswzeraAg,CAAqBwgKMPa5lwswluKuAw,CAAqBwgKMPb0lwswgZ6vAw,CAAqBwgKMKnsmAsw4fKwAw,CAAqBwgKMKjalwsw2oOvAw,CAAqBwgKMNC89AowuPiuAw,CAAqBwgKMPrWlwswrICvAw,CAAqBwgKMILDmAswtcmwAw,CAAqBwgKMM6wmAsw4rqwAw,CAAqBwgKMM-_mAswi7uwAw,CAAqBwgKMOy-mAsws8mwAw,CAAqBwgKMO3NmAsw_tewAw,CAAqBwgKMO6-mAswtsmwAw,CAAqBwgKMO2-mAswtMmwAw,CAAqBwgKMPe-mAswwMmwAw,CAAqBwgKMIXDmAswuMmwAw,CAAqBwgKMPO-mAswvcmwAw,CAAqBwgKMNTomAswt_awAw,CAAqBwgKMJLOmAswhNiwAw,CAAqBwgKMMPemAsw0-iwAw,CAAqBwgKMM_omAsw3_KwAw,CAAqBwgKMPa-mAswh9ywAw,CAAqBwgKMPTRmAswkdmwAw,CAAqBwgKMJbfmAswpumwAw,CAAqBwgKMMfwmAsw1_qwAw,CAAqBwgKMNK_mAswj7uwAw,CAAqBwgKMM7wmAsw-vqwAw,CAAqBwgKMOfwmAsw-_qwAw,CAAqBwgKMOC2mgsw08SyAw,CAAqBwgKMOC6mgsw-sSyAw,CAAqBwgKMO2-mAswtMmwAw,CAAqBwgKMMTJmgsw3tOyAw,CAAqBwgKMOG6mgsw-8SyAw,CAAqBwgKMN-2mgsw-cCyAw,CAAqBwgKMLm6mgsw1MSyAw','Wlqc5JcCHoITsfmOUUzf4w','DSwUr7JUNxiRpp8RdAQVlw','DEFAULT','English (United States)','', 2022.0 ,'https:\/\/news.google.com\/search', null ,'ltr', false ,'https:\/\/accounts.google.com\/AccountChooser?continue\x3dhttps:\/\/news.google.com\/search?q%3Dmicrosoft%26%26hl%3Den-US%26gl%3DUS%26ceid%3DUS:en\x26hl\x3den-US','\/\/accounts.google.com\/ServiceLogin?continue\x3dhttps:\/\/news.google.com\/search?q%3Dmicrosoft%26%26hl%3Den-US%26gl%3DUS%26ceid%3DUS:en\x26hl\x3den-US','https:\/\/accounts.google.com\/ServiceLogin?hl\x3den-US\x26continue\x3dhttps:\/\/news.google.com\/search?q%3Dmicrosoft%26%26hl%3Den-US%26gl%3DUS%26ceid%3DUS:en','https:\/\/accounts.google.com\/SignOutOptions?continue\x3dhttps:\/\/news.google.com\/search?q%3Dmicrosoft%26%26hl%3Den-US%26gl%3DUS%26ceid%3DUS:en','US','en-US', true , false , true , false , false , false , false , false , false , false , true ,'en','en-US','English (United States)','\/\/www.google.com\/preferences?hl\x3den-US ...
