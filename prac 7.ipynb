# %%
import csv 

import pandas as pd



with open(r"C:\Users\HP\Downloads\list_symbols_euronext.csv", 'r') as file:
    csvfile = csv.reader(file)
    for row in csvfile:
        print(row)
        break

with open(r"C:\Users\HP\Downloads\list_symbols_US.csv", 'r') as file:
    csvfile = csv.reader(file)
    for row in csvfile:
        print(row)
        break
# Out:
# ['ALMIL.PA', '2020.OL', '2CRSI.PA', '5PG.OL', 'MLATV.PA', 'ALAST.PA', 'AALB.AS', 'AASB.OL', 'ABI.BR', 'AB.PA', '-.', 'ABCA.PA', 'ABEO.PA', 'ABG.OL', 'ABNX.PA', 'ABVX.PA', 'ABLD.PA', 'ABL.OL', 'ABN.AS', 'ABO.BR', 'ACAN.PA', 'ACCB.BR', 'AC.PA', 'AAC.PA', 'AACW.PA', 'AXS.AS', 'ALALO.PA', 'ACKB.BR', 'ACOMO.AS', 'EOS.PA', 'ATI.PA', 'ALACT.PA', 'MLACT.PA', '-.', 'ALDV.PA', 'ALARF.PA', 'ADE.OL', 'ADOC.PA', 'ALADO.PA', 'ADP.PA', 'ADS.OL', 'ADUX.PA', 'ALDVI.PA', 'ADVI.PA', 'ADYEN.AS', 'AED.BR', 'AEGA.OL', 'AGN.AS', 'AELIS.PA', 'AKOM.PA', 'AFG.OL', 'AFMDS.PA', 'AFME.PA', 'ALAFY.PA', 'MLAGI.PA', 'AGS.BR', 'MLAA.PA', '-.', 'AGFB.BR', 'AGLX.OL', 'MLAGP.PA', 'ALAGP.PA', 'ALAGR.PA', 'CUR.LI', 'AD.AS', 'A5G.IR', 'AINMT.OL', 'AF.PA', 'AI.PA', 'MLAIM.PA', 'AIR.PA', 'AIRX.OL', 'MLAIR.PA', 'AJAX.AS', 'AKAST.OL', 'AKER.OL', 'AKBM.OL', 'AKRBP.OL', 'ACC.OL', 'AKH.OL', 'AKSO.OL', 'AKOBO.OL', 'AKVA.OL', 'AKW.PA', 'AKZA.AS', 'AAA.PA', 'ABIO.PA', 'ABIBS.PA', 'ALCHI.PA', 'ALD.PA', 'MLALE.PA', 'ALFEN.AS', 'ALGRE
# ...

# %%
list1, list2, list3 = [], [], []

with open(r"C:\Users\HP\Downloads\list_symbols_euronext.csv", 'r') as file:
    csvfile = csv.reader(file)
    for row in csvfile:
        for x in row:
            list1.append(x)

with open(r"C:\Users\HP\Downloads\list_symbols_US.csv", 'r') as file:
    csvfile = csv.reader(file)
    for row in csvfile:
        for x in row:
            list1.append(x)

print(list1)
# Out:
# ['ALMIL.PA', '2020.OL', '2CRSI.PA', '5PG.OL', 'MLATV.PA', 'ALAST.PA', 'AALB.AS', 'AASB.OL', 'ABI.BR', 'AB.PA', '-.', 'ABCA.PA', 'ABEO.PA', 'ABG.OL', 'ABNX.PA', 'ABVX.PA', 'ABLD.PA', 'ABL.OL', 'ABN.AS', 'ABO.BR', 'ACAN.PA', 'ACCB.BR', 'AC.PA', 'AAC.PA', 'AACW.PA', 'AXS.AS', 'ALALO.PA', 'ACKB.BR', 'ACOMO.AS', 'EOS.PA', 'ATI.PA', 'ALACT.PA', 'MLACT.PA', '-.', 'ALDV.PA', 'ALARF.PA', 'ADE.OL', 'ADOC.PA', 'ALADO.PA', 'ADP.PA', 'ADS.OL', 'ADUX.PA', 'ALDVI.PA', 'ADVI.PA', 'ADYEN.AS', 'AED.BR', 'AEGA.OL', 'AGN.AS', 'AELIS.PA', 'AKOM.PA', 'AFG.OL', 'AFMDS.PA', 'AFME.PA', 'ALAFY.PA', 'MLAGI.PA', 'AGS.BR', 'MLAA.PA', '-.', 'AGFB.BR', 'AGLX.OL', 'MLAGP.PA', 'ALAGP.PA', 'ALAGR.PA', 'CUR.LI', 'AD.AS', 'A5G.IR', 'AINMT.OL', 'AF.PA', 'AI.PA', 'MLAIM.PA', 'AIR.PA', 'AIRX.OL', 'MLAIR.PA', 'AJAX.AS', 'AKAST.OL', 'AKER.OL', 'AKBM.OL', 'AKRBP.OL', 'ACC.OL', 'AKH.OL', 'AKSO.OL', 'AKOBO.OL', 'AKVA.OL', 'AKW.PA', 'AKZA.AS', 'AAA.PA', 'ABIO.PA', 'ABIBS.PA', 'ALCHI.PA', 'ALD.PA', 'MLALE.PA', 'ALFEN.AS', 'ALGRE
# ...

# %%
url = "https://query1.finance.yahoo.com/v7/finance/download/”SYM”?period1=0&period2=1661904000&interval=1d&events=history&includeAdjustedClose=true”
